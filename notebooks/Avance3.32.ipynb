# %% [markdown]
# # Avance 3: Baseline y Evaluacion del Modelo
# # Proyecto Integrador - Equipo 32
#
# **Integrantes:**
# - Luis Mauricio Castro Gutierrez - A01795088
# - Gerardo Miguel Perez Solis - A01795599
# - Amiel Joel Rosete Islas - A01748598
#
# ---
#
# Este notebook construye un modelo baseline para predecir casos de sarampion y establecer medidas de calidad del modelo. El baseline sirve como referencia minima y marco para comparar modelos mas avanzados.

# %% [markdown]
# ## Objetivos y preguntas
# **Objetivos:**
# - 3.1 Establecer medidas de calidad del modelo de aprendizaje automatico.
# - 3.2 Proporcionar un marco de referencia para evaluar y mejorar modelos mas avanzados.
#
# **Preguntas guia:**
# - Que algoritmo es adecuado como baseline para el objetivo?
# - Que tan relevantes son las caracteristicas? (seleccion y/o importancia)
# - Hay signos de subajuste o sobreajuste?
# - Que metrica es la mas adecuada para el negocio?
# - Cual debe ser el desempeno minimo aceptable?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

from sklearn.model_selection import TimeSeriesSplit, learning_curve, GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.inspection import permutation_importance

sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (10, 5)

print("Librerias cargadas")
# Out:
# Librerias cargadas

# %%
# Rutas
base_path = Path.cwd().parent
data_path = base_path / "data" / "processed"
file_path = data_path / "dataset_sarampion_features_engineered.csv"

df = pd.read_csv(file_path)
print(f"Dataset cargado: {file_path}")
print(f"Shape: {df.shape}")
display(df.head())
# Out:
# Dataset cargado: c:\Users\LmCas\OneDrive\Documentos\Desarrollo\Maestria\Proyecto Integrado\pi-equipo32\data\processed\dataset_sarampion_features_engineered.csv
# Shape: (168, 34)
#    anio  mes  casos_sarampion  casos_rolling_mean_3m  casos_rolling_mean_6m  \
# 0  2010    1                0                    0.0                    0.0
# 1  2010    2                0                    0.0                    0.0
# 2  2010    3                0                    0.0                    0.0
# 3  2010    4                0                    0.0                    0.0
# 4  2010    5                0                    0.0                    0.0
#
#    casos_lag_1m  casos_lag_2m  tasa_casos_por_millon_dosis  casos_total_anual  \
# 0           0.0           0.0                          0.0                125
# 1           0.0           0.0                          0.0                125
# 2           0.0           0.0                          0.0                125
# ...
